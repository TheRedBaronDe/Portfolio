# %%
import pandas as pd

df = pd.read_csv(r'C:\Users\User\OneDrive\Documents\Datasets\Monthly_Rates_of_Laboratory-Confirmed_COVID-19_Hospitalizations_from_the_COVID-NET_Surveillance_System.csv')

df.head(10)
# Out:
#   State   Season  Year Month Age Category  Sex                 Race  \
# 0    NM  2022-23    202304.0          All  All  White, non-Hispanic
# 1    NM  2022-23    202212.0          All  All  White, non-Hispanic
# 2    NM  2022-23    202301.0          All  All  White, non-Hispanic
# 3    NM  2022-23    202210.0          All  All  White, non-Hispanic
# 4    NM  2022-23    202308.0          All  All  White, non-Hispanic
# 5    NM  2022-23    202307.0          All  All  White, non-Hispanic
# 6    NM  2022-23    202305.0          All  All  White, non-Hispanic
# 7    NM  2022-23    202302.0          All  All  White, non-Hispanic
# 8    NM  2022-23    202306.0          All  All  White, non-Hispanic
# 9    NM  2022-23    202303.0          All  All  White, non-Hispanic
#
#    Monthly Rate Rate Type
# 0          34.1  Observed
# 1          64.1  Observed
# 2          35.9  Observed
# 3          68.4  Observed
# 4          14.8  Observed
# 5           5.9  Observed
# 6          21.5  Observed
# ...

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 45558 entries, 0 to 45557
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   State         45558 non-null  str
#  1   Season        45558 non-null  str
#  2   Year Month    45558 non-null  float64
#  3   Age Category  45558 non-null  str
#  4   Sex           45558 non-null  str
#  5   Race          45558 non-null  str
#  6   Monthly Rate  45558 non-null  float64
#  7   Rate Type     45558 non-null  str
# dtypes: float64(2), str(6)
# memory usage: 2.8 MB

# %%
df.isnull().sum()
# Out:
# State           0
# Season          0
# Year Month      0
# Age Category    0
# Sex             0
# Race            0
# Monthly Rate    0
# Rate Type       0
# dtype: int64

# %%
df.columns = df.columns.str.lower()
df.columns = df.columns.str.replace(' ', '_')

# %%
df.columns
# Out:
# Index(['state', 'season', 'year_month', 'age_category', 'sex', 'race',
#        'monthly_rate', 'rate_type'],
#       dtype='str')

# %%
pip install psycopg-binary --only-binary psycopg-binary
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.0.1 -> 26.1
# [notice] To update, run: C:\Users\User\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
pip install sqlalchemy
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.0.1 -> 26.1
# [notice] To update, run: C:\Users\User\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
import pandas as pd
from sqlalchemy import create_engine
df = pd.read_csv(r'C:\Users\User\OneDrive\Documents\Datasets\Monthly_Rates_of_Laboratory-Confirmed_COVID-19_Hospitalizations_from_the_COVID-NET_Surveillance_System.csv', 
                encoding='utf-8')

username = "postgres"
password = "Deutsch"
host = "localhost"
port = "5432"
database = "CovidMHR"

engine = create_engine(f"postgresql+psycopg://{username}:{password}@{host}:{port}/{database}")

table_name = "Monthly"
df.to_sql(table_name, engine, if_exists="replace", index=False)

print(f"Data successfully loaded into table '{table_name}' in databate '{database}'.")
# Out:
# Data successfully loaded into table 'Monthly' in databate 'CovidMHR'.
